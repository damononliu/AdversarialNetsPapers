# %% [markdown]
# <a href="https://colab.research.google.com/github/damononliu/AdversarialNetsPapers/blob/master/btc_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
import datetime
import numpy as np
import gc

# import the relevant Keras modules
# !pip install -q keras # this is not required if you are not using Google's colab
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %matplotlib inline

# %%
neurons = 512                 # number of hidden units in the LSTM layer
activation_function = 'tanh'  # activation function for LSTM and Dense layer
loss = 'mse'                  # loss function for calculating the gradient, in this case Mean Squared Error
optimizer= 'adam'             # optimizer for appljying gradient decent
dropout = 0.25                # dropout ratio used after each LSTM layer to avoid overfitting
batch_size = 128              
epochs = 53                  
window_len = 7               # is an intiger to be used as the look back window for creating a single input sample.
training_size = 0.8           # porportion of data to be used for training
merge_date = '2016-01-01'     # the earliest date which we have data for both ETH and BTC or any other provided coin

# %%
def get_market_data(market, tag=True):
  """
  market: the full name of the cryptocurrency as spelled on coinmarketcap.com. eg.: 'bitcoin'
  tag: eg.: 'btc', if provided it will add a tag to the name of every column.
  returns: panda DataFrame
  This function will use the coinmarketcap.com url for provided coin/token page. 
  Reads the OHLCV and Market Cap.
  Converts the date format to be readable. 
  Makes sure that the data is consistant by converting non_numeric values to a number very close to 0.
  And finally tags each columns if provided.
  """
  market_data = pd.read_html("https://coinmarketcap.com/currencies/" + market + 
                             "/historical-data/?start=20130428&end="+time.strftime("%Y%m%d"), flavor='html5lib')[0]
  market_data = market_data.assign(Date=pd.to_datetime(market_data['Date']))  
  market_data['Volume'] = (pd.to_numeric(market_data['Volume'], errors='coerce').fillna(0))
  if tag:
    market_data.columns = [market_data.columns[0]] + [tag + '_' + i for i in market_data.columns[1:]]
  return market_data


def merge_data(a, b, from_date=merge_date):
  """
  a: first DataFrame
  b: second DataFrame
  from_date: includes the data from the provided date and drops the any data before that date.
  returns merged data as Pandas DataFrame
  """
  merged_data = pd.merge(a, b, on=['Date'])
  merged_data = merged_data[merged_data['Date'] >= from_date]
  return merged_data


def add_volatility(data, coins=['BTC', 'ETH']):
  """
  data: input data, pandas DataFrame
  coins: default is for 'btc and 'eth'. It could be changed as needed
  This function calculates the volatility and close_off_high of each given coin in 24 hours, 
  and adds the result as new columns to the DataFrame.
  Return: DataFrame with added columns
  """
  for coin in coins:
    # calculate the daily change
    kwargs = {coin + '_change': lambda x: (x[coin + '_Close'] - x[coin + '_Open']) / x[coin + '_Open'],
             coin + '_close_off_high': lambda x: 2*(x[coin + '_High'] - x[coin + '_Close']) / (x[coin + '_High'] - x[coin + '_Low']) - 1,
             coin + '_volatility': lambda x: (x[coin + '_High'] - x[coin + '_Low']) / (x[coin + '_Open'])}
    data = data.assign(**kwargs)
  return data


def create_model_data(data):
  """
  data: pandas DataFrame
  This function drops unnecessary columns and reverses the order of DataFrame based on decending dates.
  Return: pandas DataFrame
  """
  #data = data[['Date']+[coin+metric for coin in ['btc_', 'eth_'] for metric in ['Close','Volume','close_off_high','volatility']]]
  data = data[['Date']+[coin+metric for coin in ['BTC_', 'ETH_'] for metric in ['Close','Volume']]]
  data = data.sort_values(by='Date')
  return data


def split_data(data, training_size=0.8):
  """
  data: Pandas Dataframe
  training_size: proportion of the data to be used for training
  This function splits the data into training_set and test_set based on the given training_size
  Return: train_set and test_set as pandas DataFrame
  """
  return data[:int(training_size*len(data))], data[int(training_size*len(data)):]


def create_inputs(data, coins=['BTC', 'ETH'], window_len=window_len):
  """
  data: pandas DataFrame, this could be either training_set or test_set
  coins: coin datas which will be used as the input. Default is 'btc', 'eth'
  window_len: is an intiger to be used as the look back window for creating a single input sample.
  This function will create input array X from the given dataset and will normalize 'Close' and 'Volume' between 0 and 1
  Return: X, the input for our model as a python list which later needs to be converted to numpy array.
  """
  norm_cols = [coin + metric for coin in coins for metric in ['_Close', '_Volume']]
  inputs = []
  for i in range(len(data) - window_len):
    temp_set = data[i:(i + window_len)].copy()
    inputs.append(temp_set)
    for col in norm_cols:
      inputs[i].loc[:, col] = inputs[i].loc[:, col] / inputs[i].loc[:, col].iloc[0] - 1  
  return inputs


def create_outputs(data, coin, window_len=window_len):
  """
  data: pandas DataFrame, this could be either training_set or test_set
  coin: the target coin in which we need to create the output labels for
  window_len: is an intiger to be used as the look back window for creating a single input sample.
  This function will create the labels array for our training and validation and normalize it between 0 and 1
  Return: Normalized numpy array for 'Close' prices of the given coin
  """
  return (data[coin + '_Close'][window_len:].values / data[coin + '_Close'][:-window_len].values) - 1


def to_array(data):
  """
  data: DataFrame
  This function will convert list of inputs to a numpy array
  Return: numpy array
  """
  x = [np.array(data[i]) for i in range (len(data))]
  return np.array(x)


def build_model(inputs, output_size, neurons, activ_func=activation_function, dropout=dropout, loss=loss, optimizer=optimizer):
  """
  inputs: input data as numpy array
  output_size: number of predictions per input sample
  neurons: number of neurons/ units in the LSTM layer
  active_func: Activation function to be used in LSTM layers and Dense layer
  dropout: dropout ration, default is 0.25
  loss: loss function for calculating the gradient
  optimizer: type of optimizer to backpropagate the gradient
  This function will build 3 layered RNN model with LSTM cells with dripouts after each LSTM layer 
  and finally a dense layer to produce the output using keras' sequential model.
  Return: Keras sequential model and model summary
  """
  model = Sequential()
  model.add(LSTM(neurons, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2]), activation=activ_func))
  model.add(Dropout(dropout))
  model.add(LSTM(neurons, return_sequences=True, activation=activ_func))
  model.add(Dropout(dropout))
  model.add(LSTM(neurons, activation=activ_func))
  model.add(Dropout(dropout))
  model.add(Dense(units=output_size))
  model.add(Activation(activ_func))
  model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])
  model.summary()
  return model

# %%
def show_plot(data, tag):
  fig, (ax1, ax2) = plt.subplots(2,1, gridspec_kw = {'height_ratios':[3, 1]})
  ax1.set_ylabel('Closing Price ($)',fontsize=12)
  ax2.set_ylabel('Volume ($ bn)',fontsize=12)
  ax2.set_yticks([int('%d000000000'%i) for i in range(10)])
  ax2.set_yticklabels(range(10))
  ax1.set_xticks([datetime.date(i,j,1) for i in range(2013,2019) for j in [1,7]])
  ax1.set_xticklabels('')
  ax2.set_xticks([datetime.date(i,j,1) for i in range(2013,2019) for j in [1,7]])
  ax2.set_xticklabels([datetime.date(i,j,1).strftime('%b %Y')  for i in range(2013,2019) for j in [1,7]])
  ax1.plot(data['Date'].astype(datetime.datetime),data[tag +'_Open'])
  ax2.bar(data['Date'].astype(datetime.datetime).values, data[tag +'_Volume'].values)
  fig.tight_layout()
  plt.show()
  

def date_labels():
  last_date = market_data.iloc[0, 0]
  date_list = [last_date - datetime.timedelta(days=x) for x in range(len(X_test))]
  return[date.strftime('%m/%d/%Y') for date in date_list][::-1]


def plot_results(history, model, Y_target, coin):
  plt.figure(figsize=(25, 20))
  plt.subplot(311)
  plt.plot(history.epoch, history.history['loss'], )
  plt.plot(history.epoch, history.history['val_loss'])
  plt.xlabel('Number of Epochs')
  plt.ylabel('Loss')
  plt.title(coin + ' Model Loss')
  plt.legend(['Training', 'Test'])

  plt.subplot(312)
  plt.plot(Y_target)
  plt.plot(model.predict(X_train))
  plt.xlabel('Dates')
  plt.ylabel('Price')
  plt.title(coin + ' Single Point Price Prediction on Training Set')
  plt.legend(['Actual','Predicted'])

  ax1 = plt.subplot(313)
  plt.plot(test_set[coin + '_Close'][window_len:].values.tolist())
  plt.plot(((np.transpose(model.predict(X_test)) + 1) * test_set[coin + '_Close'].values[:-window_len])[0])
  plt.xlabel('Dates')
  plt.ylabel('Price')
  plt.title(coin + ' Single Point Price Prediction on Test Set')
  plt.legend(['Actual','Predicted'])
  
  date_list = date_labels()
  ax1.set_xticks([x for x in range(len(date_list))])
  for label in ax1.set_xticklabels([date for date in date_list], rotation='vertical')[::2]:
    label.set_visible(False)

  plt.show()

# %%
btc_data = get_market_data("bitcoin", tag="BTC")

# %%
eth_data = get_market_data("ethereum", tag='ETH')

# %%
eth_data.head()
# Out:
#         Date  ETH_Open*  ETH_High  ...  ETH_Close**   ETH_Volume  ETH_Market Cap
# 0 2019-11-05     186.31    191.26  ...       189.30  10024177342     20528094420
# 1 2019-11-04     182.32    188.02  ...       186.36  10551917945     20205859402
# 2 2019-11-03     183.99    185.02  ...       182.43   8760247744     19777347724
# 3 2019-11-02     184.02    185.71  ...       183.93   8087991830     19937622287
# 4 2019-11-01     183.80    185.06  ...       183.97   9145611130     19940014311
#
# [5 rows x 7 columns]

# %%
btc_data.head()
# Out:
#         Date  BTC_Open*  BTC_High  ...  BTC_Close**    BTC_Volume  BTC_Market Cap
# 0 2019-11-05    9413.00   9457.42  ...      9342.53  2.619861e+10    168459778835
# 1 2019-11-04    9235.61   9505.05  ...      9412.61  2.617026e+10    169706332936
# 2 2019-11-03    9324.79   9379.81  ...      9235.35  2.113222e+10    166495319475
# 3 2019-11-02    9259.78   9377.49  ...      9324.72  2.124268e+10    168090392935
# 4 2019-11-01    9193.99   9275.66  ...      9261.10  2.432469e+10    166928044164
#
# [5 rows x 7 columns]

# %%
btc_data.rename(columns={"BTC_Open*":"BTC_Open", "BTC_Close**":"BTC_Close"}, inplace=True)
eth_data.rename(columns={"ETH_Open*":"ETH_Open", "ETH_Close**":"ETH_Close"}, inplace=True)
btc_data.head()
# Out:
#         Date  BTC_Open  BTC_High  ...  BTC_Close    BTC_Volume  BTC_Market Cap
# 0 2019-11-05   9413.00   9457.42  ...    9342.53  2.619861e+10    168459778835
# 1 2019-11-04   9235.61   9505.05  ...    9412.61  2.617026e+10    169706332936
# 2 2019-11-03   9324.79   9379.81  ...    9235.35  2.113222e+10    166495319475
# 3 2019-11-02   9259.78   9377.49  ...    9324.72  2.124268e+10    168090392935
# 4 2019-11-01   9193.99   9275.66  ...    9261.10  2.432469e+10    166928044164
#
# [5 rows x 7 columns]

# %%
eth_data.head()
# Out:
#         Date  ETH_Open  ETH_High  ...  ETH_Close   ETH_Volume  ETH_Market Cap
# 0 2019-11-05    186.31    191.26  ...     189.30  10024177342     20528094420
# 1 2019-11-04    182.32    188.02  ...     186.36  10551917945     20205859402
# 2 2019-11-03    183.99    185.02  ...     182.43   8760247744     19777347724
# 3 2019-11-02    184.02    185.71  ...     183.93   8087991830     19937622287
# 4 2019-11-01    183.80    185.06  ...     183.97   9145611130     19940014311
#
# [5 rows x 7 columns]

# %%
show_plot(eth_data, tag="ETH")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-12169e2dc853> in <module>()
# ----> 1 show_plot(eth_data, tag="ETH")
#
# <ipython-input-137-546f7f9e1f82> in show_plot(data, tag)
#       9   ax2.set_xticks([datetime.date(i,j,1) for i in range(2013,2019) for j in [1,7]])
#      10   ax2.set_xticklabels([datetime.date(i,j,1).strftime('%b %Y')  for i in range(2013,2019) for j in [1,7]])
# ---> 11   ax1.plot(data['Date'].astype(datetime.datetime),data[tag +'_Open'])
#      12   ax2.bar(data['Date'].astype(datetime.datetime).values, data[tag +'_Volume'].values)
#      13   fig.tight_layout()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in _astype(self, dtype, **kwargs)
#    2253         raise on an except if raise == True
#    2254         """
# -> 2255         dtype = pandas_dtype(dtype)
#    2256
#    2257         # if we are passed a datetime64[ns, tz]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    2065         return npdtype
#    2066     elif npdtype.kind == "O":
# -> 2067         raise TypeError("dtype '{}' not understood".format(dtype))
#    2068
#    2069     return npdtype
#
# TypeError: dtype '<class 'datetime.datetime'>' not understood

# %%
market_data = merge_data(btc_data, eth_data)
model_data = create_model_data(market_data)
train_set, test_set = split_data(model_data)

# %%
train_set.head()
# Out:
#            Date  BTC_Close  BTC_Volume  ETH_Close  ETH_Volume
# 1404 2016-01-01     434.33  36278900.0   0.948024      206062
# 1403 2016-01-02     433.44  30096600.0   0.937124      255504
# 1402 2016-01-03     430.01  39633800.0   0.971905      407632
# 1401 2016-01-04     433.09  38477500.0   0.954480      346245
# 1400 2016-01-05     431.96  34522600.0   0.950176      219833

# %%
model_data[0:5]
# Out:
#            Date  BTC_Close  BTC_Volume  ETH_Close  ETH_Volume
# 1404 2016-01-01     434.33  36278900.0   0.948024      206062
# 1403 2016-01-02     433.44  30096600.0   0.937124      255504
# 1402 2016-01-03     430.01  39633800.0   0.971905      407632
# 1401 2016-01-04     433.09  38477500.0   0.954480      346245
# 1400 2016-01-05     431.96  34522600.0   0.950176      219833

# %%
train_set = train_set.drop('Date', 1)
test_set = test_set.drop('Date', 1)
X_train = create_inputs(train_set)
Y_train_btc = create_outputs(train_set, coin='BTC')
X_test = create_inputs(test_set)
Y_test_btc = create_outputs(test_set, coin='BTC')

Y_train_eth = create_outputs(train_set, coin='ETH')
Y_test_eth = create_outputs(test_set, coin='ETH')

X_train, X_test = to_array(X_train), to_array(X_test)

print (np.shape(X_train), np.shape(X_test), np.shape(Y_train_btc), np.shape(Y_test_btc))
print (np.shape(X_train), np.shape(X_test), np.shape(Y_train_eth), np.shape(Y_test_eth))
# Out:
# (1117, 7, 4) (274, 7, 4) (1117,) (274,)
# (1117, 7, 4) (274, 7, 4) (1117,) (274,)

# %%
# clean up the memory
gc.collect()

# random seed for reproducibility
np.random.seed(202)

from keras.utils import plot_model
# initialise model architecture
btc_model = build_model(X_train, output_size=1, neurons=neurons)
plot_model(btc_model, show_shapes=True)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 7, 512)            1058816
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 7, 512)            0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 7, 512)            2099200
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 7, 512)            0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 512)               2099200
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,257,729
# Trainable params: 5,257,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train model on data
btc_history = btc_model.fit(X_train, Y_train_btc, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_test, Y_test_btc), shuffle=False)

# %%
plot_results(btc_history, btc_model, Y_train_btc, coin='BTC')

# %%
# clean up the memory
gc.collect()

# random seed for reproducibility
np.random.seed(202)

# initialise model architecture
eth_model = build_model(X_train, output_size=1, neurons=neurons)

# train model on data
eth_history = eth_model.fit(X_train, Y_train_eth, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(X_test, Y_test_eth), shuffle=False)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 7, 512)            1058816
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 7, 512)            2099200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,257,729
# Trainable params: 5,257,729
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1117 samples, validate on 274 samples
# Epoch 1/53
# 1117/1117 [==============================] - 12s 11ms/step - loss: 0.0513 - mean_absolute_error: 0.1534 - val_loss: 0.0087 - val_mean_absolute_error: 0.0691
# Epoch 2/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0309 - mean_absolute_error: 0.1194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0532
# Epoch 3/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0193 - mean_absolute_error: 0.0966 - val_loss: 0.0050 - val_mean_absolute_error: 0.0542
# Epoch 4/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0156 - mean_absolute_error: 0.0846 - val_loss: 0.0041 - val_mean_absolute_error: 0.0486
# Epoch 5/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0184 - mean_absolute_error: 0.0907 - val_loss: 0.0038 - val_mean_absolute_error: 0.0440
# Epoch 6/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0135 - mean_absolute_error: 0.0795 - val_loss: 0.0035 - val_mean_absolute_error: 0.0431
# Epoch 7/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0121 - mean_absolute_error: 0.0734 - val_loss: 0.0032 - val_mean_absolute_error: 0.0410
# Epoch 8/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0111 - mean_absolute_error: 0.0682 - val_loss: 0.0029 - val_mean_absolute_error: 0.0383
# Epoch 9/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0638 - val_loss: 0.0027 - val_mean_absolute_error: 0.0373
# Epoch 10/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0627 - val_loss: 0.0028 - val_mean_absolute_error: 0.0383
# Epoch 11/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0087 - mean_absolute_error: 0.0598 - val_loss: 0.0024 - val_mean_absolute_error: 0.0347
# Epoch 12/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0079 - mean_absolute_error: 0.0579 - val_loss: 0.0023 - val_mean_absolute_error: 0.0341
# Epoch 13/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0073 - mean_absolute_error: 0.0558 - val_loss: 0.0023 - val_mean_absolute_error: 0.0337
# Epoch 14/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0556 - val_loss: 0.0022 - val_mean_absolute_error: 0.0329
# Epoch 15/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0072 - mean_absolute_error: 0.0548 - val_loss: 0.0022 - val_mean_absolute_error: 0.0322
# Epoch 16/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0070 - mean_absolute_error: 0.0548 - val_loss: 0.0023 - val_mean_absolute_error: 0.0329
# Epoch 17/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0532 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 18/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0518 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 19/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0530 - val_loss: 0.0022 - val_mean_absolute_error: 0.0324
# Epoch 20/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0534 - val_loss: 0.0022 - val_mean_absolute_error: 0.0319
# Epoch 21/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0529 - val_loss: 0.0021 - val_mean_absolute_error: 0.0307
# Epoch 22/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0519 - val_loss: 0.0020 - val_mean_absolute_error: 0.0308
# Epoch 23/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0517 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 24/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0529 - val_loss: 0.0021 - val_mean_absolute_error: 0.0313
# Epoch 25/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0512 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 26/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0514 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 27/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0072 - mean_absolute_error: 0.0544 - val_loss: 0.0024 - val_mean_absolute_error: 0.0343
# Epoch 28/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0071 - mean_absolute_error: 0.0542 - val_loss: 0.0022 - val_mean_absolute_error: 0.0323
# Epoch 29/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0535 - val_loss: 0.0020 - val_mean_absolute_error: 0.0302
# Epoch 30/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0064 - mean_absolute_error: 0.0522 - val_loss: 0.0020 - val_mean_absolute_error: 0.0304
# Epoch 31/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0522 - val_loss: 0.0023 - val_mean_absolute_error: 0.0334
# Epoch 32/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0072 - mean_absolute_error: 0.0543 - val_loss: 0.0021 - val_mean_absolute_error: 0.0319
# Epoch 33/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0536 - val_loss: 0.0020 - val_mean_absolute_error: 0.0303
# Epoch 34/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0525 - val_loss: 0.0020 - val_mean_absolute_error: 0.0302
# Epoch 35/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0524 - val_loss: 0.0023 - val_mean_absolute_error: 0.0335
# Epoch 36/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0531 - val_loss: 0.0020 - val_mean_absolute_error: 0.0309
# Epoch 37/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0523 - val_loss: 0.0020 - val_mean_absolute_error: 0.0303
# Epoch 38/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0503 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 39/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0507 - val_loss: 0.0020 - val_mean_absolute_error: 0.0309
# Epoch 40/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0505 - val_loss: 0.0020 - val_mean_absolute_error: 0.0304
# Epoch 41/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0504 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 42/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0505 - val_loss: 0.0020 - val_mean_absolute_error: 0.0305
# Epoch 43/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0512 - val_loss: 0.0020 - val_mean_absolute_error: 0.0306
# Epoch 44/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0512 - val_loss: 0.0020 - val_mean_absolute_error: 0.0302
# Epoch 45/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0501 - val_loss: 0.0022 - val_mean_absolute_error: 0.0323
# Epoch 46/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0523 - val_loss: 0.0024 - val_mean_absolute_error: 0.0341
# Epoch 47/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0536 - val_loss: 0.0023 - val_mean_absolute_error: 0.0339
# Epoch 48/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0520 - val_loss: 0.0020 - val_mean_absolute_error: 0.0302
# Epoch 49/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0514 - val_loss: 0.0020 - val_mean_absolute_error: 0.0304
# Epoch 50/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0498 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 51/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0059 - mean_absolute_error: 0.0497 - val_loss: 0.0021 - val_mean_absolute_error: 0.0313
# Epoch 52/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0508 - val_loss: 0.0021 - val_mean_absolute_error: 0.0311
# Epoch 53/53
# 1117/1117 [==============================] - 8s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0511 - val_loss: 0.0020 - val_mean_absolute_error: 0.0306

# %%
plot_results(eth_history, eth_model, Y_train_eth, coin='ETH')
